# %%
import pandas as pd
pd.set_option("display.max_rows", None)
df = pd.read_csv('../data/interim/csv_files/2018_Monaco_R_organized.csv')

df.head()
# Out:
#    sessionkey  lap_count  lap_mean   lap_std  lap_best  lap_median  \
# 0         984       78.0  79.85775  4.605667     74.26      79.036
# 1         984       78.0  79.85775  4.605667     74.26      79.036
# 2         984       78.0  79.85775  4.605667     74.26      79.036
# 3         984       78.0  79.85775  4.605667     74.26      79.036
# 4         984       78.0  79.85775  4.605667     74.26      79.036
#
#    air_temp_mean  air_temp_min  air_temp_max  track_temp_mean  ...  \
# 0      26.640708          25.3          27.6        34.609735  ...
# 1      26.640708          25.3          27.6        34.609735  ...
# 2      26.640708          25.3          27.6        34.609735  ...
# 3      26.640708          25.3          27.6        34.609735  ...
# 4      26.640708          25.3          27.6        34.609735  ...
#
#    vsc_ending_duration_in_seconds  sc_duration_in_seconds  \
# 0                          11.788                     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 66 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   sessionkey                      20 non-null     int64
#  1   lap_count                       20 non-null     float64
#  2   lap_mean                        20 non-null     float64
#  3   lap_std                         20 non-null     float64
#  4   lap_best                        20 non-null     float64
#  5   lap_median                      20 non-null     float64
#  6   air_temp_mean                   20 non-null     float64
#  7   air_temp_min                    20 non-null     float64
#  8   air_temp_max                    20 non-null     float64
#  9   track_temp_mean                 20 non-null     float64
#  10  track_temp_min                  20 non-null     float64
#  11  track_temp_max                  20 non-null     float64
# ...

# %%
df.shape
# Out:
# (20, 66)

# %%
# Missing values check
missing = df.isnull().sum().sort_values(ascending=False)
missing_percentage = (missing / len(df)) * 100

print("Missing Values Count:")
print(missing)
print("Missing Values Percentage:")
print(missing_percentage)
# Out:
# Missing Values Count:
# q2                                20
# q1                                20
# q3                                20
# headshoturl                       20
# time                               7
# sessionkey                         0
# lap_count                          0
# lap_mean                           0
# lap_best                           0
# lap_std                            0
# track_temp_min                     0
# track_temp_max                     0
# humidity_mean                      0
# lap_median                         0
# air_temp_mean                      0
# air_temp_min                       0
# air_temp_max                       0
# track_temp_mean                    0
# rain_any                           0
# rain_samples_ratio                 0
# rain_samples                       0
# air_temp_std                       0
# track_temp_std                     0
# humidity_std                       0
# wind_speed_std                     0
# ...

# %% [markdown]
# ## <font color='teal'>q1, q2, q3 are missing because at this time only one race session data is processed. Need to drop headshoturl, firstname, lastname, broadcastname, fullname columns. They hold no value for the model.</font>

# %%
duplicate_rows = df.duplicated()
print(f"Number of duplicate rows: {duplicate_rows.sum()}")
# Out:
# Number of duplicate rows: 0
